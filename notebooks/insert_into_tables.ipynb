# %%
# =========================================
# insert_into_tables.ipynb
# Calls existing insert_banks.py and insert_reviews.py
# =========================================

import os
import sys

# Ensure parent dir in path to import modules
CURRENT_DIR = os.path.dirname(os.path.abspath("__file__"))
PARENT_DIR = os.path.dirname(CURRENT_DIR)
sys.path.append(PARENT_DIR)

# Import the working functions
from src.insert_banks import load_app_info, insert_banks
from src.insert_reviews import load_and_merge, insert_reviews

# -----------------------------------------
# 1️⃣ Insert Banks
# -----------------------------------------
df_banks = load_app_info()
insert_banks(df_banks)

# -----------------------------------------
# 2️⃣ Insert Reviews
# -----------------------------------------
df_reviews = load_and_merge()
insert_reviews(df_reviews)

print("🎉 All tables updated successfully!")
